# %%
import matplotlib.pyplot as plt 

a = [1,2,34,4]

b = [2,4,5,3]
plt.plot(a,b)
plt.show()

# %%
import csv
import requests

url = 'https://www-usr.inf.ufsm.br/~joaquim/UFSM/DM/ds/vendas_lucro.csv'

with requests.Session() as s:
    download = s.get(url)
    dd = download.content.decode('utf-8')

print (download.content)


df1 = csv.reader(dd.splitlines(), delimiter=',')    # dialect=csv.excel_tab)

for row in df1:
    print(row)


# print (df[1][4])
# Out:
# b'Vendas,Lucro\r\n1200,7941\r\n1100,8410\r\n400,3001\r\n300,2401\r\n129,3400\r\n469,3200\r\n800,3000\r\n1500,12045\r\n999,999\r\n111,333\r\n'
# ['Vendas', 'Lucro']
# ['1200', '7941']
# ['1100', '8410']
# ['400', '3001']
# ['300', '2401']
# ['129', '3400']
# ['469', '3200']
# ['800', '3000']
# ['1500', '12045']
# ['999', '999']
# ['111', '333']

# %%
import pandas as pd

df2 = pd.read_csv('https://www-usr.inf.ufsm.br/~joaquim/UFSM/DM/ds/vendas_lucro.csv')

# df2 = pd.read_html('https://www-usr.inf.ufsm.br/~joaquim/UFSM/DM/ds/vendas_lucro.csv')

df2 = pd.DataFrame(df2)

# print(df2.to_string())
# print (df2[1][1])

# df3 = pd.DataFrame(df2.data,
#     columns= df2.feature_names)

print(df2.loc[df2[1]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 15
#       7 df2 = pd.DataFrame(df2)
#       9 # print(df2.to_string())
# ...
